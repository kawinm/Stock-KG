# %%
# !pip install finpie
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\kawin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=b91a55c1d219f383b7c26e772d7c54c66de491d9a5dda9eb0566fa896c58f46d
#   Stored in directory: c:\users\kawin\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=63afcef7cc8a33d96f1b65f42ed9ff9aea7f5de5c351fa14572cd62a834e6008
#   Stored in directory: c:\users\kawin\appdata\local\pip\cache\wheels\d6\9c\58\ee3ba36897e890f3ad81e9b730791a153fce20caa4a8a474df
# Successfully built bs4 parse
# ...

# %%
import finpie # or import finpie.fundamental_data

# default:
# source = 'macrotrends'
# freq = 'A'
fd = finpie.Fundamentals("AAPL", source = 'macrotrends', freq = 'A')

# source options for financial statements and key metrics:
# 'yahoo', 'marketwatch', 'macrotrends'
# freq options:
# 'A', 'Q'

# default key metrics for marketwatch and macrotrends come from Finviz

# %%
fd.income_statement()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.78M/6.78M [00:00<00:00, 9.19MB/s]
#             revenue  cost_of_goods_sold  gross_profit  \
# date
# 2009-09-30  42905.0                 NaN           NaN
# 2009-09-30      NaN                 NaN           NaN
# 2009-09-30      NaN                 NaN       17222.0
# 2009-09-30      NaN                 NaN           NaN
# 2009-09-30      NaN                 NaN           NaN
# ...             ...                 ...           ...
# 2022-09-30      NaN                 NaN           NaN
# 2022-09-30      NaN                 NaN           NaN
# 2022-09-30      NaN                 NaN           NaN
# 2022-09-30      NaN                 NaN           NaN
# 2022-09-30      NaN                 NaN           NaN
#
#             research_and_development_expenses  sganda_expenses  \
# date
# 2009-09-30                                NaN              NaN
# 2009-09-30                                NaN              NaN
# ...

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\kawin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
msft.quarterly_income_stmt
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# e:\stock_kg\extract.ipynb Cell 5 in <module>
# ----> <a href='vscode-notebook-cell:/e%3A/stock_kg/extract.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> msft.quarterly_income_stmt
#
# File c:\Users\kawin\AppData\Local\Programs\Python\Python39\lib\site-packages\yfinance\ticker.py:162, in Ticker.quarterly_income_stmt(self)
#     160 @property
#     161 def quarterly_income_stmt(self) -> _pd.DataFrame:
# --> 162     return self.get_income_stmt(pretty=True, freq='quarterly')
#
# File c:\Users\kawin\AppData\Local\Programs\Python\Python39\lib\site-packages\yfinance\base.py:1582, in TickerBase.get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1580     data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1581 else:
# ...

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get all stock info (slow)
#print(msft.info)
# fast access to subset of stock info (opportunistic)
#print(msft.fast_info)

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
print(msft.history_metadata)

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
# - yearly summary:
msft.shares
# - accurate time-series count:
msft.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations
msft.recommendations_summary
# show analysts other work
msft.analyst_price_target
msft.revenue_forecasts
msft.earnings_forecasts
msft.earnings_trend

# show next event (earnings, etc)
msft.calendar

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
# Out:
# {'currency': 'USD', 'symbol': 'MSFT', 'exchangeName': 'NMS', 'instrumentType': 'EQUITY', 'firstTradeDate': Timestamp('1986-03-13 09:30:00-0500', tz='America/New_York'), 'regularMarketTime': Timestamp('2023-03-03 16:00:04-0500', tz='America/New_York'), 'gmtoffset': -18000, 'timezone': 'EST', 'exchangeTimezoneName': 'America/New_York', 'regularMarketPrice': 255.29, 'chartPreviousClose': 258.35, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'start': Timestamp('2023-03-06 04:00:00-0500', tz='America/New_York'), 'end': Timestamp('2023-03-06 09:30:00-0500', tz='America/New_York')}, 'regular': {'start': Timestamp('2023-03-06 09:30:00-0500', tz='America/New_York'), 'end': Timestamp('2023-03-06 16:00:00-0500', tz='America/New_York')}, 'post': {'start': Timestamp('2023-03-06 16:00:00-0500', tz='America/New_York'), 'end': Timestamp('2023-03-06 20:00:00-0500', tz='America/New_York')}}, 'dataGranularity': '1d', 'range': '1mo', 'validRanges': ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', 
# ...

# %%
# !pip install fundamentalanalysis
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\kawin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import fundamentalanalysis as fa

ticker = "MSFT"
api_key = "6eb8c70712a889b4f7efbf8d8ad902d4"

# Show the available companies
companies = fa.available_companies(api_key)

# Collect general company information
profile = fa.profile(ticker, api_key)

# Collect recent company quotes
quotes = fa.quote(ticker, api_key)

# Collect market cap and enterprise value
entreprise_value = fa.enterprise(ticker, api_key)

# Show recommendations of Analysts
ratings = fa.rating(ticker, api_key)

# Obtain DCFs over time
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")

# Collect the Balance Sheet statements
balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")

# Collect the Income Statements
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")

# Collect the Cash Flow Statements
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")

# Show Key Metrics
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")

# Show a large set of in-depth ratios
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")

# Show the growth of the company
growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")

# Download general stock data
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")

# Download detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2023-01-01")

# Download dividend history
dividends = fa.stock_dividend(ticker, api_key, begin="2000-01-01", end="2023-01-01")

# %%
from urllib.request import urlopen
import certifi
import json

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/stock_news?tickers=AAPL&page=0&apikey=6eb8c70712a889b4f7efbf8d8ad902d4")
print(get_jsonparsed_data(url))
# Out:
# C:\Users\kawin\AppData\Local\Temp\ipykernel_20364\2297419880.py:17: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# e:\stock_kg\extract.ipynb Cell 9 in <module>
#      <a href='vscode-notebook-cell:/e%3A/stock_kg/extract.ipynb#X23sZmlsZQ%3D%3D?line=18'>19</a>     return json.loads(data)
#      <a href='vscode-notebook-cell:/e%3A/stock_kg/extract.ipynb#X23sZmlsZQ%3D%3D?line=20'>21</a> url = ("https://financialmodelingprep.com/api/v3/stock_news?tickers=AAPL&page=0&apikey=6eb8c70712a889b4f7efbf8d8ad902d4")
# ---> <a href='vscode-notebook-cell:/e%3A/stock_kg/extract.ipynb#X23sZmlsZQ%3D%3D?line=21'>22</a> print(get_jsonparsed_data(url))
#
# e:\stock_kg\extract.ipynb Cell 9 in get_jsonparsed_data(url)
# ...

# %%
print(growth_annually)
# Out:
#                                             2022      2021      2020  \
# period                                        FY        FY        FY
# revenueGrowth                           0.179561  0.175317  0.136456
# grossProfitGrowth                       0.170591  0.195168  0.168859
# ebitgrowth                              0.192617  0.320191   0.23278
# operatingIncomeGrowth                   0.192617  0.320191   0.23278
# netIncomeGrowth                         0.187152  0.383686  0.128466
# epsgrowth                               0.194581  0.395189  0.138943
# epsdilutedGrowth                        0.198758  0.397569   0.13834
# weightedAverageSharesGrowth            -0.006758 -0.008279 -0.008211
# weightedAverageSharesDilutedGrowth     -0.008938 -0.009762 -0.009029
# dividendsperShareGrowth                 0.105162  0.100543  0.105084
# operatingCashFlowGrowth                 0.160216  0.264771   0.16269
# freeCashFlowGrowth                      0.160929  0.240615  0.182279
# ...

# %%
# Show the growth of the company
growth_quar = fa.financial_statement_growth(ticker, api_key, period="quarter")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\kawin\AppData\Local\Programs\Python\Python39\lib\site-packages\fundamentalanalysis\ratios.py:148, in financial_statement_growth(ticker, api_key, period, limit)
#     147 try:
# --> 148     response = urlopen(f"https://financialmodelingprep.com/api/v3/financial-growth/{ticker}"
#     149                        f"?period={period}&limit={limit}&apikey={api_key}")
#     150     data = json.loads(response.read().decode("utf-8"))
#
# File c:\Users\kawin\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\kawin\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
# ...

# %%
profile.loc[['symbol', 'price']]
# Out:
#              0
# symbol    MSFT
# price   250.21

# %%
profile
# Out:
#                                                                    0
# symbol                                                          MSFT
# price                                                         250.21
# beta                                                         0.91562
# volAvg                                                      31403096
# mktCap                                                 1862513214013
# lastDiv                                                         2.54
# range                                                  213.43-315.95
# changes                                                         3.94
# companyName                                    Microsoft Corporation
# currency                                                         USD
# cik                                                       0000789019
# isin                                                    US5949181045
# cusip                                                      594918104
# ...

# %%
# !pip install yahooquery
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\kawin\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
from yahooquery import Ticker

aapl = Ticker('aapl')

aapl.summary_detail
# Out:
# {'aapl': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 145.91,
#   'open': 148.045,
#   'dayLow': 147.335,
#   'dayHigh': 151.11,
#   'regularMarketPreviousClose': 145.91,
#   'regularMarketOpen': 148.045,
#   'regularMarketDayLow': 147.335,
#   'regularMarketDayHigh': 151.11,
#   'dividendRate': 0.92,
#   'dividendYield': 0.0063,
#   'exDividendDate': '2023-02-10 05:30:00',
#   'payoutRatio': 0.1545,
#   'fiveYearAvgDividendYield': 0.95,
#   'beta': 1.277894,
#   'trailingPE': 24.678104,
#   'forwardPE': 22.952888,
#   'volume': 70661207,
#   'regularMarketVolume': 70661207,
#   'averageVolume': 73469776,
#   'averageVolume10days': 54681750,
#   'averageDailyVolume10Day': 54681750,
#   'bid': 0.0,
#   'ask': 0.0,
#   'bidSize': 1200,
#   'askSize': 900,
#   'marketCap': 2389581496320,
#   'fiftyTwoWeekLow': 124.17,
#   'fiftyTwoWeekHigh': 179.61,
#   'priceToSalesTrailing12Months': 6.166073,
#   'fiftyDayAverage': 141.4736,
#   'twoHundredDayAverage': 147.2074,
# ...

# %%
aapl.balance_sheet(frequency="a")
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# aapl   2019-09-30        12M          USD     4.623600e+10
# aapl   2020-09-30        12M          USD     4.229600e+10
# aapl   2021-09-30        12M          USD     5.476300e+10
# aapl   2022-09-30        12M          USD     6.411500e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# aapl          2.292600e+10            -5.857900e+10
# aapl          1.612000e+10            -6.676000e+10
# aapl          2.627800e+10            -7.028300e+10
# aapl          2.818400e+10            -7.234000e+10
#
#         AvailableForSaleSecurities  CapitalStock  CashAndCashEquivalents  \
# symbol
# aapl                  1.053410e+11  4.517400e+10            4.884400e+10
# aapl                  1.008870e+11  5.077900e+10            3.801600e+10
# aapl                  1.278770e+11  5.736500e+10            3.494000e+10
# aapl                  1.208050e+11  6.484900e+10            2.364600e+10
#
# ...

# %%
aapl.income_statement()
# Out:
#          asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# aapl   2019-09-30        12M          USD        1.847134e+10    2.9925
# aapl   2020-09-30        12M          USD        1.735212e+10    3.3100
# aapl   2021-09-30        12M          USD        1.670127e+10    5.6700
# aapl   2022-09-30        12M          USD        1.621596e+10    6.1500
# aapl   2022-12-31        TTM          USD                 NaN       NaN
#
#         CostOfRevenue  DilutedAverageShares  DilutedEPS  \
# symbol
# aapl     1.617820e+11          1.859565e+10      2.9725
# aapl     1.695590e+11          1.752821e+10      3.2800
# aapl     2.129810e+11          1.686492e+10      5.6100
# aapl     2.235460e+11          1.632582e+10      6.1100
# aapl     2.206660e+11                   NaN         NaN
#
#         DilutedNIAvailtoComStockholders          EBIT  ...  \
# symbol                                                 ...
# ...

# %%
import re
import json
import pandas as pd
import requests
import os

sp500 = {'MNST': ['Monster Beverage', 'Consumer Staples'], 'GNRC': ['Generac Holdings', 'Industrials'], 'SLB': ['Schlumberger', 'Energy'], 'PWR': ['Quanta Services', 'Industrials'], 'RCL': ['Royal Caribbean Group', 'Consumer Discretionary'], 'UAL': ['United Airlines', 'Industrials'], 'EQIX': ['Equinix', 'Real Estate'], 'INTC': ['Intel', 'Information Technology'], 'DOV': ['Dover Corporation', 'Industrials'], 'IP': ['International Paper', 'Materials'], 'FOXA': ['Fox Corporation (Class A)', 'Communication Services'], 'AIZ': ['Assurant', 'Financials'], 'SYK': ['Stryker Corporation', 'Health Care'], 'ADSK': ['Autodesk', 'Information Technology'], 'QRVO': ['Qorvo', 'Information Technology'], 'ALLE': ['Allegion', 'Industrials'], 'CARR': ['Carrier Global', 'Industrials'], 'DXC': ['DXC Technology', 'Information Technology'], 'HON': ['Honeywell', 'Industrials'], 'NTRS': ['Northern Trust', 'Financials'], 'MPC': ['Marathon Petroleum', 'Energy'], 'ROP': ['Roper Technologies', 'Industrials'], 'FTNT': ['Fortinet', 'Information Technology'], 'EVRG': ['Evergy', 'Utilities'], 'IFF': ['International Flavors & Fragrances', 'Materials'], 'SO': ['Southern Company', 'Utilities'], 'AEP': ['American Electric Power', 'Utilities'], 'MLM': ['Martin Marietta Materials', 'Materials'], 'FIS': ['Fidelity National Information Services', 'Information Technology'], 'F': ['Ford', 'Consumer Discretionary'], 'SWKS': ['Skyworks Solutions', 'Information Technology'], 'SBAC': ['SBA Communications', 'Real Estate'], 'AON': ['Aon', 'Financials'], 'MET': ['MetLife', 'Financials'], 'ODFL': ['Old Dominion Freight Line', 'Industrials'], 'BAC': ['Bank of America', 'Financials'], 'GLW': ['Corning', 'Information Technology'], 'RL': ['Ralph Lauren Corporation', 'Consumer Discretionary'], 'HES': ['Hess Corporation', 'Energy'], 'WAT': ['Waters Corporation', 'Health Care'], 'RSG': ['Republic Services', 'Industrials'], 'BAX': ['Baxter International', 'Health Care'], 'MDLZ': ['Mondelez International', 'Consumer Staples'], 'RF': ['Regions Financial Corporation', 'Financials'], 'SPGI': ['S&P Global', 'Financials'], 'LNT': ['Alliant Energy', 'Utilities'], 'CMG': ['Chipotle Mexican Grill', 'Consumer Discretionary'], 'ILMN': ['Illumina', 'Health Care'], 'LYV': ['Live Nation Entertainment', 'Communication Services'], 'VRSK': ['Verisk Analytics', 'Industrials'], 'ALGN': ['Align Technology', 'Health Care'], 'MS': ['Morgan Stanley', 'Financials'], 'AMGN': ['Amgen', 'Health Care'], 'XOM': ['ExxonMobil', 'Energy'], 'ROK': ['Rockwell Automation', 'Industrials'], 'REGN': ['Regeneron Pharmaceuticals', 'Health Care'], 'LEN': ['Lennar', 'Consumer Discretionary'], 'HIG': ['The Hartford', 'Financials'], 'DE': ['Deere & Co.', 'Industrials'], 'POOL': ['Pool Corporation', 'Consumer Discretionary'], 'LMT': ['Lockheed Martin', 'Industrials'], 'WHR': ['Whirlpool Corporation', 'Consumer Discretionary'], 'DRI': ['Darden Restaurants', 'Consumer Discretionary'], 'EOG': ['EOG Resources', 'Energy'], 'FRT': ['Federal Realty Investment Trust', 'Real Estate'], 'BBWI': ['Bath & Body Works Inc.', 'Consumer Discretionary'], 'CDNS': ['Cadence Design Systems', 'Information Technology'], 'NOC': ['Northrop Grumman', 'Industrials'], 'CAT': ['Caterpillar', 'Industrials'], 'DD': ['DuPont', 'Materials'], 'HSY': ['The Hershey Company', 'Consumer Staples'], 'WYNN': ['Wynn Resorts', 'Consumer Discretionary'], 'WELL': ['Welltower', 'Real Estate'], 'FISV': ['Fiserv', 'Information Technology'], 'NI': ['NiSource', 'Utilities'], 'NWS': ['News Corp (Class B)', 'Communication Services'], 'EMR': ['Emerson Electric Company', 'Industrials'], 'DUK': ['Duke Energy', 'Utilities'], 'ECL': ['Ecolab', 'Materials'], 'ABC': ['AmerisourceBergen', 'Health Care'], 'APD': ['Air Products & Chemicals', 'Materials'], 'MKC': ['McCormick & Company', 'Consumer Staples'], 'BKNG': ['Booking Holdings', 'Consumer Discretionary'], 'SEE': ['Sealed Air', 'Materials'], 'EQR': ['Equity Residential', 'Real Estate'], 'LYB': ['LyondellBasell', 'Materials'], 'ISRG': ['Intuitive Surgical', 'Health Care'], 'UAA': ['Under Armour (Class A)', 'Consumer Discretionary'], 'JCI': ['Johnson Controls', 'Industrials'], 'LHX': ['L3Harris Technologies', 'Industrials'], 'INCY': ['Incyte', 'Health Care'], 'SHW': ['SherwinWilliams', 'Materials'], 'NXPI': ['NXP', 'Information Technology'], 'HPQ': ['HP', 'Information Technology'], 'MCD': ["McDonald's", 'Consumer Discretionary'], 'ATO': ['Atmos Energy', 'Utilities'], 'SJM': ['JM Smucker', 'Consumer Staples'], 'TFX': ['Teleflex', 'Health Care'], 'DLR': ['Digital Realty Trust', 'Real Estate'], 'ADI': ['Analog Devices', 'Information Technology'], 'LUMN': ['Lumen Technologies', 'Communication Services'], 'GWW': ['W. W. Grainger', 'Industrials'], 'UHS': ['Universal Health Services', 'Health Care'], 'DHR': ['Danaher Corporation', 'Health Care'], 'MRNA': ['Moderna', 'Health Care'], 'FFIV': ['F5 Networks', 'Information Technology'], 'ITW': ['Illinois Tool Works', 'Industrials'], 'K': ["Kellogg's", 'Consumer Staples'], 'MMC': ['Marsh & McLennan', 'Financials'], 'MSCI': ['MSCI', 'Financials'], 'UPS': ['United Parcel Service', 'Industrials'], 'CTAS': ['Cintas Corporation', 'Industrials'], 'GOOGL': ['Alphabet (Class A)', 'Communication Services'], 'ORCL': ['Oracle', 'Information Technology'], 'UNH': ['UnitedHealth Group', 'Health Care'], 'UA': ['Under Armour (Class C)', 'Consumer Discretionary'], 'JKHY': ['Jack Henry & Associates', 'Information Technology'], 'PNW': ['Pinnacle West Capital', 'Utilities'], 'KMB': ['KimberlyClark', 'Consumer Staples'], 'CE': ['Celanese', 'Materials'], 'PTC': ['PTC', 'Information Technology'], 'MAA': ['MidAmerica Apartments', 'Real Estate'], 'CVX': ['Chevron Corporation', 'Energy'], 'NCLH': ['Norwegian Cruise Line Holdings', 'Consumer Discretionary'], 'COST': ['Costco', 'Consumer Staples'], 'VRTX': ['Vertex Pharmaceuticals', 'Health Care'], 'CPRT': ['Copart', 'Industrials'], 'IQV': ['IQVIA', 'Health Care'], 'SNPS': ['Synopsys', 'Information Technology'], 'EW': ['Edwards Lifesciences', 'Health Care'], 'BIO': ['BioRad Laboratories', 'Health Care'], 'LNC': ['Lincoln National', 'Financials'], 'WRB': ['W. R. Berkley Corporation', 'Financials'], 'TWTR': ['Twitter', 'Communication Services'], 'AEE': ['Ameren Corp', 'Utilities'], 'ANSS': ['Ansys', 'Information Technology'], 'SPG': ['Simon Property Group', 'Real Estate'], 'CINF': ['Cincinnati Financial', 'Financials'], 'C': ['Citigroup', 'Financials'], 'DXCM': ['DexCom', 'Health Care'], 'KEYS': ['Keysight Technologies', 'Information Technology'], 'ADP': ['Automatic Data Processing', 'Information Technology'], 'HBI': ['Hanesbrands', 'Consumer Discretionary'], 'IBM': ['IBM', 'Information Technology'], 'HPE': ['Hewlett Packard Enterprise', 'Information Technology'], 'DIS': ['The Walt Disney Company', 'Communication Services'], 'EXR': ['Extra Space Storage', 'Real Estate'], 'ZION': ['Zions Bancorp', 'Financials'], 'WU': ['Western Union', 'Information Technology'], 'ALK': ['Alaska Air Group', 'Industrials'], 'EA': ['Electronic Arts', 'Communication Services'], 'LKQ': ['LKQ Corporation', 'Consumer Discretionary'], 'TSN': ['Tyson Foods', 'Consumer Staples'], 'ACN': ['Accenture', 'Information Technology'], 'STZ': ['Constellation Brands', 'Consumer Staples'], 'TXN': ['Texas Instruments', 'Information Technology'], 'CF': ['CF Industries', 'Materials'], 'UNP': ['Union Pacific', 'Industrials'], 'MTCH': ['Match Group', 'Communication Services'], 'OGN': ['Organon & Co.', 'Health Care'], 'FRC': ['First Republic Bank', 'Financials'], 'MPWR': ['Monolithic Power Systems', 'Information Technology'], 'PSA': ['Public Storage', 'Real Estate'], 'MTB': ['M&T Bank', 'Financials'], 'PNR': ['Pentair', 'Industrials'], 'NVR': ['NVR', 'Consumer Discretionary'], 'HRL': ['Hormel', 'Consumer Staples'], 'PLD': ['Prologis', 'Real Estate'], 'L': ['Loews Corporation', 'Financials'], 'ABMD': ['Abiomed', 'Health Care'], 'CI': ['Cigna', 'Health Care'], 'EFX': ['Equifax', 'Industrials'], 'MMM': ['3M', 'Industrials'], 'FOX': ['Fox Corporation (Class B)', 'Communication Services'], 'EXC': ['Exelon', 'Utilities'], 'TAP': ['Molson Coors Beverage Company', 'Consumer Staples'], 'HII': ['Huntington Ingalls Industries', 'Industrials'], 'KIM': ['Kimco Realty', 'Real Estate'], 'NDAQ': ['Nasdaq', 'Financials'], 'WMB': ['Williams Companies', 'Energy'], 'DGX': ['Quest Diagnostics', 'Health Care'], 'SBUX': ['Starbucks', 'Consumer Discretionary'], 'WY': ['Weyerhaeuser', 'Real Estate'], 'TRV': ['The Travelers Companies', 'Financials'], 'PCAR': ['Paccar', 'Industrials'], 'JBHT': ['J. B. Hunt', 'Industrials'], 'KLAC': ['KLA Corporation', 'Information Technology'], 'TECH': ['BioTechne', 'Health Care'], 'CHTR': ['Charter Communications', 'Communication Services'], 'APTV': ['Aptiv', 'Consumer Discretionary'], 'VTRS': ['Viatris', 'Health Care'], 'NKE': ['Nike', 'Consumer Discretionary'], 'ULTA': ['Ulta Beauty', 'Consumer Discretionary'], 'TROW': ['T. Rowe Price', 'Financials'], 'CTRA': ['Coterra', 'Energy'], 'A': ['Agilent Technologies', 'Health Care'], 'IEX': ['IDEX Corporation', 'Industrials'], 'AAPL': ['Apple', 'Information Technology'], 'NEM': ['Newmont', 'Materials'], 'URI': ['United Rentals', 'Industrials'], 'GS': ['Goldman Sachs', 'Financials'], 'NRG': ['NRG Energy', 'Utilities'], 'V': ['Visa', 'Information Technology'], 'ETR': ['Entergy', 'Utilities'], 'HST': ['Host Hotels & Resorts', 'Real Estate'], 'AMT': ['American Tower', 'Real Estate'], 'ABT': ['Abbott Laboratories', 'Health Care'], 'AVB': ['AvalonBay Communities', 'Real Estate'], 'EL': ['Estée Lauder Companies', 'Consumer Staples'], 'GIS': ['General Mills', 'Consumer Staples'], 'BKR': ['Baker Hughes', 'Energy'], 'FMC': ['FMC Corporation', 'Materials'], 'PRU': ['Prudential Financial', 'Financials'], 'WMT': ['Walmart', 'Consumer Staples'], 'DG': ['Dollar General', 'Consumer Discretionary'], 'RTX': ['Raytheon Technologies', 'Industrials'], 'RJF': ['Raymond James Financial', 'Financials'], 'CMI': ['Cummins', 'Industrials'], 'KEY': ['KeyCorp', 'Financials'], 'MDT': ['Medtronic', 'Health Care'], 'COP': ['ConocoPhillips', 'Energy'], 'PPG': ['PPG Industries', 'Materials'], 'MAS': ['Masco', 'Industrials'], 'HSIC': ['Henry Schein', 'Health Care'], 'ORLY': ["O'Reilly Automotive", 'Consumer Discretionary'], 'GPS': ['Gap', 'Consumer Discretionary'], 'O': ['Realty Income Corporation', 'Real Estate'], 'NOW': ['ServiceNow', 'Information Technology'], 'DPZ': ["Domino's Pizza", 'Consumer Discretionary'], 'MCK': ['McKesson Corporation', 'Health Care'], 'DHI': ['D. R. Horton', 'Consumer Discretionary'], 'BLK': ['BlackRock', 'Financials'], 'STE': ['Steris', 'Health Care'], 'ROL': ['Rollins', 'Industrials'], 'VLO': ['Valero Energy', 'Energy'], 'ZBH': ['Zimmer Biomet', 'Health Care'], 'PG': ['Procter & Gamble', 'Consumer Staples'], 'ANET': ['Arista Networks', 'Information Technology'], 'WST': ['West Pharmaceutical Services', 'Health Care'], 'MRK': ['Merck & Co.', 'Health Care'], 'AVGO': ['Broadcom', 'Information Technology'], 'LDOS': ['Leidos', 'Industrials'], 'NVDA': ['Nvidia', 'Information Technology'], 'MCHP': ['Microchip Technology', 'Information Technology'], 'CTLT': ['Catalent', 'Health Care'], 'AMCR': ['Amcor', 'Materials'], 'BXP': ['Boston Properties', 'Real Estate'], 'PNC': ['PNC Financial Services', 'Financials'], 'HCA': ['HCA Healthcare', 'Health Care'], 'CRM': ['Salesforce', 'Information Technology'], 'PENN': ['Penn National Gaming', 'Consumer Discretionary'], 'LLY': ['Eli Lilly & Co', 'Health Care'], 'BDX': ['Becton Dickinson', 'Health Care'], 'IT': ['Gartner', 'Information Technology'], 'APH': ['Amphenol', 'Information Technology'], 'ADBE': ['Adobe', 'Information Technology'], 'DLTR': ['Dollar Tree', 'Consumer Discretionary'], 'LOW': ["Lowe's", 'Consumer Discretionary'], 'BK': ['BNY Mellon', 'Financials'], 'IPGP': ['IPG Photonics', 'Information Technology'], 'TEL': ['TE Connectivity', 'Information Technology'], 'CPB': ['Campbell Soup', 'Consumer Staples'], 'VFC': ['VF Corporation', 'Consumer Discretionary'], 'GE': ['General Electric', 'Industrials'], 'AKAM': ['Akamai Technologies', 'Information Technology'], 'SCHW': ['Charles Schwab Corporation', 'Financials'], 'OTIS': ['Otis Worldwide', 'Industrials'], 'EXPD': ['Expeditors', 'Industrials'], 'PFG': ['Principal Financial Group', 'Financials'], 'AJG': ['Arthur J. Gallagher & Co.', 'Financials'], 'CCL': ['Carnival Corporation', 'Consumer Discretionary'], 'PH': ['ParkerHannifin', 'Industrials'], 'DAL': ['Delta Air Lines', 'Industrials'], 'LRCX': ['Lam Research', 'Information Technology'], 'CAH': ['Cardinal Health', 'Health Care'], 'VTR': ['Ventas', 'Real Estate'], 'TDY': ['Teledyne Technologies', 'Industrials'], 'BRO': ['Brown & Brown', 'Financials'], 'CBRE': ['CBRE', 'Real Estate'], 'VRSN': ['Verisign', 'Information Technology'], 'CHRW': ['C. H. Robinson', 'Industrials'], 'PEAK': ['Healthpeak Properties', 'Real Estate'], 'STX': ['Seagate Technology', 'Information Technology'], 'AXP': ['American Express', 'Financials'], 'CNC': ['Centene Corporation', 'Health Care'], 'EBAY': ['eBay', 'Consumer Discretionary'], 'MO': ['Altria Group', 'Consumer Staples'], 'CNP': ['CenterPoint Energy', 'Utilities'], 'XRAY': ['Dentsply Sirona', 'Health Care'], 'FTV': ['Fortive', 'Industrials'], 'WM': ['Waste Management', 'Industrials'], 'BWA': ['BorgWarner', 'Consumer Discretionary'], 'ZTS': ['Zoetis', 'Health Care'], 'NFLX': ['Netflix', 'Communication Services'], 'ENPH': ['Enphase Energy', 'Information Technology'], 'LEG': ['Leggett & Platt', 'Consumer Discretionary'], 'MRO': ['Marathon Oil', 'Energy'], 'ROST': ['Ross Stores', 'Consumer Discretionary'], 'PAYC': ['Paycom', 'Information Technology'], 'BR': ['Broadridge Financial Solutions', 'Information Technology'], 'RE': ['Everest Re', 'Financials'], 'BMY': ['Bristol Myers Squibb', 'Health Care'], 'MSI': ['Motorola Solutions', 'Information Technology'], 'CMA': ['Comerica', 'Financials'], 'HLT': ['Hilton Worldwide', 'Consumer Discretionary'], 'TPR': ['Tapestry', 'Consumer Discretionary'], 'AES': ['AES Corp', 'Utilities'], 'KR': ['Kroger', 'Consumer Staples'], 'CSCO': ['Cisco Systems', 'Information Technology'], 'CMS': ['CMS Energy', 'Utilities'], 'GPC': ['Genuine Parts', 'Consumer Discretionary'], 'CME': ['CME Group', 'Financials'], 'JPM': ['JPMorgan Chase', 'Financials'], 'FE': ['FirstEnergy', 'Utilities'], 'MHK': ['Mohawk Industries', 'Consumer Discretionary'], 'WEC': ['WEC Energy Group', 'Utilities'], 'ED': ['Consolidated Edison', 'Utilities'], 'HAS': ['Hasbro', 'Consumer Discretionary'], 'AIG': ['American International Group', 'Financials'], 'PPL': ['PPL', 'Utilities'], 'ALL': ['Allstate Corp', 'Financials'], 'IDXX': ['Idexx Laboratories', 'Health Care'], 'MAR': ['Marriott International', 'Consumer Discretionary'], 'ZBRA': ['Zebra Technologies', 'Information Technology'], 'FDX': ['FedEx', 'Industrials'], 'DISH': ['Dish Network', 'Communication Services'], 'KMI': ['Kinder Morgan', 'Energy'], 'LIN': ['Linde', 'Materials'], 'TYL': ['Tyler Technologies', 'Information Technology'], 'HOLX': ['Hologic', 'Health Care'], 'CRL': ['Charles River Laboratories', 'Health Care'], 'PAYX': ['Paychex', 'Information Technology'], 'SNA': ['Snapon', 'Industrials'], 'CAG': ['Conagra Brands', 'Consumer Staples'], 'HUM': ['Humana', 'Health Care'], 'INTU': ['Intuit', 'Information Technology'], 'SYF': ['Synchrony Financial', 'Financials'], 'SIVB': ['SVB Financial', 'Financials'], 'D': ['Dominion Energy', 'Utilities'], 'VMC': ['Vulcan Materials', 'Materials'], 'TDG': ['TransDigm Group', 'Industrials'], 'HBAN': ['Huntington Bancshares', 'Financials'], 'CDW': ['CDW', 'Information Technology'], 'QCOM': ['Qualcomm', 'Information Technology'], 'AFL': ['Aflac', 'Financials'], 'JNPR': ['Juniper Networks', 'Information Technology'], 'CFG': ['Citizens Financial Group', 'Financials'], 'AZO': ['AutoZone', 'Consumer Discretionary'], 'RMD': ['ResMed', 'Health Care'], 'IPG': ['Interpublic Group', 'Communication Services'], 'AMD': ['Advanced Micro Devices', 'Information Technology'], 'ARE': ['Alexandria Real Estate Equities', 'Real Estate'], 'GM': ['General Motors', 'Consumer Discretionary'], 'CCI': ['Crown Castle', 'Real Estate'], 'WRK': ['WestRock', 'Materials'], 'PYPL': ['PayPal', 'Information Technology'], 'AAL': ['American Airlines Group', 'Industrials'], 'STT': ['State Street Corporation', 'Financials'], 'CLX': ['Clorox', 'Consumer Staples'], 'GL': ['Globe Life', 'Financials'], 'TMO': ['Thermo Fisher Scientific', 'Health Care'], 'TSCO': ['Tractor Supply Company', 'Consumer Discretionary'], 'PVH': ['PVH', 'Consumer Discretionary'], 'DOW': ['Dow', 'Materials'], 'NTAP': ['NetApp', 'Information Technology'], 'PXD': ['Pioneer Natural Resources', 'Energy'], 'HAL': ['Halliburton', 'Energy'], 'PHM': ['PulteGroup', 'Consumer Discretionary'], 'KMX': ['CarMax', 'Consumer Discretionary'], 'ALB': ['Albemarle Corporation', 'Materials'], 'IRM': ['Iron Mountain', 'Real Estate'], 'RHI': ['Robert Half International', 'Industrials'], 'TER': ['Teradyne', 'Information Technology'], 'ES': ['Eversource Energy', 'Utilities'], 'DFS': ['Discover Financial Services', 'Financials'], 'CTVA': ['Corteva', 'Materials'], 'DVN': ['Devon Energy', 'Energy'], 'USB': ['U.S. Bancorp', 'Financials'], 'PSX': ['Phillips 66', 'Energy'], 'GILD': ['Gilead Sciences', 'Health Care'], 'AOS': ['A. O. Smith', 'Industrials'], 'CVS': ['CVS Health', 'Health Care'], 'CHD': ['Church & Dwight', 'Consumer Staples'], 'WAB': ['Wabtec', 'Industrials'], 'CMCSA': ['Comcast', 'Communication Services'], 'FLT': ['Fleetcor', 'Information Technology'], 'TJX': ['TJX Companies', 'Consumer Discretionary'], 'EXPE': ['Expedia Group', 'Consumer Discretionary'], 'OKE': ['Oneok', 'Energy'], 'FAST': ['Fastenal', 'Industrials'], 'XEL': ['Xcel Energy', 'Utilities'], 'IVZ': ['Invesco', 'Financials'], 'AWK': ['American Water Works', 'Utilities'], 'MOS': ['The Mosaic Company', 'Materials'], 'TMUS': ['TMobile US', 'Communication Services'], 'GPN': ['Global Payments', 'Information Technology'], 'CDAY': ['Ceridian', 'Information Technology'], 'OMC': ['Omnicom Group', 'Communication Services'], 'VZ': ['Verizon Communications', 'Communication Services'], 'KHC': ['Kraft Heinz', 'Consumer Staples'], 'BBY': ['Best Buy', 'Consumer Discretionary'], 'MCO': ["Moody's Corporation", 'Financials'], 'WDC': ['Western Digital', 'Information Technology'], 'PKI': ['PerkinElmer', 'Health Care'], 'LH': ['LabCorp', 'Health Care'], 'UDR': ['UDR', 'Real Estate'], 'LUV': ['Southwest Airlines', 'Industrials'], 'MSFT': ['Microsoft', 'Information Technology'], 'T': ['AT&T', 'Communication Services'], 'TSLA': ['Tesla', 'Consumer Discretionary'], 'PKG': ['Packaging Corporation of America', 'Materials'], 'PM': ['Philip Morris International', 'Consumer Staples'], 'COF': ['Capital One Financial', 'Financials'], 'TTWO': ['TakeTwo Interactive', 'Communication Services'], 'ESS': ['Essex Property Trust', 'Real Estate'], 'TXT': ['Textron', 'Industrials'], 'BIIB': ['Biogen', 'Health Care'], 'CSX': ['CSX', 'Industrials'], 'AAP': ['Advance Auto Parts', 'Consumer Discretionary'], 'LW': ['Lamb Weston', 'Consumer Staples'], 'ABBV': ['AbbVie', 'Health Care'], 'PEG': ['Public Service Enterprise Group', 'Utilities'], 'ICE': ['Intercontinental Exchange', 'Financials'], 'ETN': ['Eaton Corporation', 'Industrials'], 'J': ['Jacobs Engineering Group', 'Industrials'], 'AMZN': ['Amazon', 'Consumer Discretionary'], 'CB': ['Chubb', 'Financials'], 'FCX': ['FreeportMcMoRan', 'Materials'], 'MA': ['Mastercard', 'Information Technology'], 'EMN': ['Eastman Chemical', 'Materials'], 'YUM': ['Yum! Brands', 'Consumer Discretionary'], 'NEE': ['NextEra Energy', 'Utilities'], 'GOOG': ['Alphabet (Class C)', 'Communication Services'], 'EIX': ['Edison International', 'Utilities'], 'DTE': ['DTE Energy', 'Utilities'], 'BEN': ['Franklin Resources', 'Financials'], 'CBOE': ['Cboe Global Markets', 'Financials'], 'ADM': ['ADM', 'Consumer Staples'], 'AMAT': ['Applied Materials', 'Information Technology'], 'TRMB': ['Trimble', 'Information Technology'], 'TFC': ['Truist Financial', 'Financials'], 'CTSH': ['Cognizant Technology Solutions', 'Information Technology'], 'REG': ['Regency Centers', 'Real Estate'], 'PEP': ['PepsiCo', 'Consumer Staples'], 'MU': ['Micron Technology', 'Information Technology'], 'AMP': ['Ameriprise Financial', 'Financials'], 'FITB': ['Fifth Third Bancorp', 'Financials'], 'PFE': ['Pfizer', 'Health Care'], 'NWSA': ['News Corp (Class A)', 'Communication Services'], 'ATVI': ['Activision Blizzard', 'Communication Services'], 'GRMN': ['Garmin', 'Consumer Discretionary'], 'SYY': ['Sysco', 'Consumer Staples'], 'MGM': ['MGM Resorts International', 'Consumer Discretionary'], 'COO': ['The Cooper Companies', 'Health Care'], 'OXY': ['Occidental Petroleum', 'Energy'], 'BA': ['Boeing', 'Industrials'], 'XYL': ['Xylem', 'Industrials'], 'CZR': ['Caesars Entertainment', 'Consumer Discretionary'], 'NWL': ['Newell Brands', 'Consumer Discretionary'], 'MTD': ['Mettler Toledo', 'Health Care'], 'AME': ['Ametek', 'Industrials'], 'SWK': ['Stanley Black & Decker', 'Industrials'], 'APA': ['APA Corporation', 'Energy'], 'CL': ['ColgatePalmolive', 'Consumer Staples'], 'JNJ': ['Johnson & Johnson', 'Health Care'], 'SRE': ['Sempra Energy', 'Utilities'], 'WBA': ['Walgreens Boots Alliance', 'Consumer Staples'], 'NUE': ['Nucor', 'Materials'], 'BSX': ['Boston Scientific', 'Health Care'], 'HWM': ['Howmet Aerospace', 'Industrials'], 'AVY': ['Avery Dennison', 'Materials'], 'KO': ['CocaCola Company', 'Consumer Staples'], 'ETSY': ['Etsy', 'Consumer Discretionary'], 'GD': ['General Dynamics', 'Industrials'], 'TT': ['Trane Technologies', 'Industrials'], 'IR': ['Ingersoll Rand', 'Industrials'], 'NSC': ['Norfolk Southern', 'Industrials'], 'TGT': ['Target Corporation', 'Consumer Discretionary'], 'DVA': ['DaVita', 'Health Care'], 'LVS': ['Las Vegas Sands', 'Consumer Discretionary'], 'PGR': ['Progressive Corporation', 'Financials'], 'WFC': ['Wells Fargo', 'Financials'], 'MKTX': ['MarketAxess', 'Financials'], 'FANG': ['Diamondback Energy', 'Energy'], 'HD': ['Home Depot', 'Consumer Discretionary'], 'VNO': ['Vornado Realty Trust', 'Real Estate']}
nasdaq100 = {'CPRT': ['Copart Inc', 'Industrials'], 'ROST': ['Ross Stores Inc', 'Consumer Discretionary'], 'BIDU': ['Baidu Inc ADRs of Class A', 'Communication Services'], 'ODFL': ['Old Dominion Freight Line Inc', 'Industrials'], 'KDP': ['Keurig Dr Pepper Inc.', 'Consumer Staples'], 'NFLX': ['Netflix Inc', 'Communication Services'], 'SBUX': ['Starbucks Corp', 'Consumer Discretionary'], 'MELI': ['Mercadolibre Inc', 'Consumer Discretionary'], 'MRVL': ['Marvell Technology Group Ltd', 'Information Technology'], 'BIIB': ['Biogen Inc', 'Health Care'], 'INTC': ['Intel Corporation Corp', 'Information Technology'], 'SNPS': ['Synopsys Inc', 'Information Technology'], 'SGEN': ['Seattle Genetics Inc', 'Health Care'], 'DLTR': ['Dollar Tree Inc', 'Consumer Discretionary'], 'INTU': ['Intuit Inc', 'Information Technology'], 'AMZN': ['Amazon.Com Inc.', 'Consumer Discretionary'], 'NTES': ['NetEase Inc ADRs', 'Communication Services'], 'CDNS': ['Cadence Design Systems Inc', 'Information technology'], 'GILD': ['Gilead Sciences Inc', 'Health Care'], 'MDLZ': ['Mondelez International Inc', 'Consumer Staples'], 'MCHP': ['Microchip Technology Inc', 'Information Technology'], 'SIRI': ['Sirius Xm Holdings Inc', 'Communication Services'], 'DOCU': ['Docusign Inc.', 'Information Technology'], 'ORLY': ['Oreilly Automotive Inc', 'Consumer Discretionary'], 'AMGN': ['Amgen Inc', 'Health Care'], 'META': ['Meta Platforms, Inc.', 'Communication Services'], 'FISV': ['Fiserv Inc', 'Information Technology'], 'ADI': ['Analog Devices Inc', 'Information Technology'], 'MU': ['Micron Technology Inc', 'Information Technology'], 'BKNG': ['Booking Holdings Inc', 'Consumer Discretionary'], 'SWKS': ['Skyworks Solutions Inc', 'Information Technology'], 'CEG': ['Constellation Energy Corporation', 'Utilities'], 'PCAR': ['Paccar Inc', 'Industrials'], 'ADP': ['Automatic Data Processing Inc', 'Information Technology'], 'CRWD': ['CrowdStrike Holdings, Inc.  Class A', 'Information Technology'], 'AMAT': ['Applied Material Inc', 'Information Technology'], 'GOOG': ['Alphabet Inc Class C', 'Communication Services'], 'CTAS': ['Cintas Corp', 'Industrials'], 'TXN': ['Texas Instrument Inc', 'Information Technology'], 'NVDA': ['Nvidia Corp', 'Information Technology'], 'ALGN': ['Align Technology Inc', 'Health Care'], 'WDAY': ['Workday Inc', 'Information Technology'], 'NXPI': ['NXP Semiconductors Nv', 'Information Technology'], 'LRCX': ['Lam Research Corp', 'Information Technology'], 'TSLA': ['Tesla Inc', 'Consumer Discretionary'], 'ASML': ['ASML Holding NV ADRs', 'Information Technology'], 'ZM': ['Zoom Video Communications, Inc.  Class A', 'Information Technology'], 'CMCSA': ['Comcast A Corp', 'Communication Services'], 'ENPH': ['Enphase Energy Inc', 'Information Technology'], 'PANW': ['Palo Alto Networks Inc', 'Information Technology'], 'XEL': ['Xcel Energy Inc', 'Utilities'], 'ANSS': ['Ansys Inc', 'Information Technology'], 'MTCH': ['Match Group Inc', 'Communication Services'], 'TEAM': ['Atlassian Plc Class A', 'Information Technology'], 'AVGO': ['Broadcom Inc.', 'Information Technology'], 'MRNA': ['Moderna, Inc.', 'Health Care'], 'VRSN': ['Verisign Inc', 'Information Technology'], 'KLAC': ['KLATencor Corporation', 'Information Technology'], 'LULU': ['Lululemon Athletica Inc', 'Consumer Discretionary'], 'VRTX': ['Vertex Pharmaceuticals Inc', 'Health Care'], 'GOOGL': ['Alphabet Inc Class A', 'Communication Services'], 'PAYX': ['Paychex Inc', 'Information Technology'], 'ADBE': ['Adobe Inc', 'Information Technology'], 'ILMN': ['Illumina Inc', 'Health Care'], 'AAPL': ['Apple Inc', 'Information Technology'], 'AEP': ['American Electric Power Inc', 'Utilities'], 'CSCO': ['Cisco Systems Inc', 'Information Technology'], 'LCID': ['Lucid Group, Inc.', 'Consumer Discretionary'], 'VRSK': ['Verisk Analytics Inc', 'Industrials'], 'AMD': ['Advanced Micro Devices Inc', 'Information Technology'], 'EA': ['Electronic Arts Inc', 'Communication Services'], 'COST': ['Costco Wholesale Corp', 'Consumer Staples'], 'EBAY': ['Ebay Inc', 'Consumer Discretionary'], 'ISRG': ['Intuitive Surgical Inc', 'Health Care'], 'ABNB': ['Airbnb, Inc.', 'Consumer Discretionary'], 'PEP': ['Pepsico Inc', 'Consumer Staples'], 'FAST': ['Fastenal', 'Industrials'], 'MSFT': ['Microsoft Corp', 'Information Technology'], 'ATVI': ['Activision Blizzard Inc', 'Communication Services'], 'REGN': ['Regeneron Pharmaceuticals Inc', 'Health Care'], 'DDOG': ['Datadog, Inc.  Class A', 'Information Technology'], 'PDD': ['Pinduoduo Inc. ADRs', 'Consumer Discretionary'], 'CSX': ['CSX Corp', 'Industrials'], 'MNST': ['Monster Beverage Corp', 'Consumer Staples'], 'IDXX': ['Idexx Laboratories Inc', 'Health Care'], 'SPLK': ['Splunk Inc', 'Information Technology'], 'KHC': ['Kraft Heinz', 'Consumer Staples'], 'JD': ['JD.com Inc ADRs', 'Consumer Discretionary'], 'QCOM': ['Qualcomm Inc', 'Information Technology'], 'ZS': ['Zscaler Inc', 'Information Technology'], 'ADSK': ['Autodesk Inc', 'Information Technology'], 'WBA': ['Walgreen Boots Alliance Inc', 'Consumer Staples'], 'CTSH': ['Cognizant Technology Solutions', 'Information Technology'], 'FTNT': ['Fortinet Inc', 'Information Technology'], 'DXCM': ['Dexcom Inc', 'Health Care'], 'PYPL': ['Paypal Holdings Inc', 'Information Technology'], 'HON': ['Honeywell International Inc', 'Industrials'], 'CHTR': ['Charter Communications Inc Class A', 'Communication Services'], 'MAR': ['Marriott International Inc', 'Consumer Discretionary'], 'TMUS': ['T Mobile US Inc', 'Communication Services'], 'EXC': ['Exelon Corp', 'Utilities'], 'AZN': ['AstraZeneca PLC ADRs', 'Health Care']}

n, m = 0, 0
for k, v in nasdaq100.items():
    if k in sp500:
        n += 1
    else:
        sp500[k] = v
        m += 1
print(n, m)

#simply scrape
def scrape(url,**kwargs):
    
    session=requests.Session()
    session.headers.update(
            {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'})
    
    response=session.get(url,**kwargs)

    return response


#create dataframe
def etl(response):

    #regex to find the data
    num=re.findall('(?<=div\>\"\,)[0-9\.\"\:\-\, ]*',response.text)
    text=re.findall('(?<=s\: \')\S+(?=\'\, freq)',response.text)

    #convert text to dict via json
    dicts=[json.loads('{'+i+'}') for i in num]

    #create dataframe
    df=pd.DataFrame()
    for ind,val in enumerate(text):
        df[val]=dicts[ind].values()
    df.index=dicts[ind].keys()
    
    return df
# Out:
# 77 25

# %%
len(sp500.keys())
# Out:
# 511

# %%
sp500.keys()
# Out:
# dict_keys(['MNST', 'GNRC', 'SLB', 'PWR', 'RCL', 'UAL', 'EQIX', 'INTC', 'DOV', 'IP', 'FOXA', 'AIZ', 'SYK', 'ADSK', 'QRVO', 'ALLE', 'CARR', 'DXC', 'HON', 'NTRS', 'MPC', 'ROP', 'FTNT', 'EVRG', 'IFF', 'SO', 'AEP', 'MLM', 'FIS', 'F', 'SWKS', 'SBAC', 'AON', 'MET', 'ODFL', 'BAC', 'GLW', 'RL', 'HES', 'WAT', 'RSG', 'BAX', 'MDLZ', 'RF', 'SPGI', 'LNT', 'CMG', 'ILMN', 'LYV', 'VRSK', 'ALGN', 'MS', 'AMGN', 'XOM', 'ROK', 'REGN', 'LEN', 'HIG', 'DE', 'POOL', 'LMT', 'WHR', 'DRI', 'EOG', 'FRT', 'BBWI', 'CDNS', 'NOC', 'CAT', 'DD', 'HSY', 'WYNN', 'WELL', 'FISV', 'NI', 'NWS', 'EMR', 'DUK', 'ECL', 'ABC', 'APD', 'MKC', 'BKNG', 'SEE', 'EQR', 'LYB', 'ISRG', 'UAA', 'JCI', 'LHX', 'INCY', 'SHW', 'NXPI', 'HPQ', 'MCD', 'ATO', 'SJM', 'TFX', 'DLR', 'ADI', 'LUMN', 'GWW', 'UHS', 'DHR', 'MRNA', 'FFIV', 'ITW', 'K', 'MMC', 'MSCI', 'UPS', 'CTAS', 'GOOGL', 'ORCL', 'UNH', 'UA', 'JKHY', 'PNW', 'KMB', 'CE', 'PTC', 'MAA', 'CVX', 'NCLH', 'COST', 'VRTX', 'CPRT', 'IQV', 'SNPS', 'EW', 'BIO', 'LNC', 'WRB', 'TWTR', 'AEE', 'ANSS', 'S
# ...

# %%
r = requests.get('https://www.macrotrends.net/stocks/charts/AAPL/') 
print(r.url)
# Out:
# https://www.macrotrends.net/stocks/charts/AAPL/apple/

# %%
ticker_url = {}

# %%
not_found = ['TWTR', 'ABMD']

# %%
import os

# %%
info_to_download = ['financial-ratios', 'income-statement', 'balance-sheet', 'cash-flow-statement']
frequency = ['quarterly', 'annual']

for info in info_to_download:
    for freq in frequency:
        code = 'A'
        if freq == 'quarterly':
            code = 'Q'
        
        print(info, freq)
        for k, v in sp500.items():
            if os.path.isfile('macrotrends/'+info+'/'+freq+'/'+k+'-'+info+'-'+freq+'.csv'):
                print('exists')
                continue
            
            print(k)
            if k in not_found:
                print("Not found")
                continue 
            
            if k in ticker_url:
                prefix = ticker_url[k]
            else:
                r = requests.get('https://www.macrotrends.net/stocks/charts/'+k+'/') 
                ticker_url[k] = r.url
                prefix = r.url

            url = prefix +'/'+info+'?freq='+code
            #url ='https://www.macrotrends.net/stocks/charts/AAPL/apple/income-statement?freq=Q'
            response=scrape(url)
            df=etl(response)
            df.to_csv('macrotrends/'+info+'/'+freq+'/'+k+'-'+info+'-'+freq+'.csv')
# Out:
# balance-sheet quarterly
# MNST
# GNRC
# SLB
# PWR
# RCL
# UAL
# EQIX
# INTC
# DOV
# IP
# FOXA
# AIZ
# SYK
# ADSK
# QRVO
# ALLE
# CARR
# DXC
# HON
# NTRS
# MPC
# ROP
# FTNT
# EVRG
# IFF
# SO
# AEP
# MLM
# FIS
# F
# SWKS
# SBAC
# AON
# MET
# ODFL
# BAC
# GLW
# RL
# HES
# WAT
# RSG
# BAX
# MDLZ
# RF
# SPGI
# LNT
# CMG
# ILMN
# LYV
# VRSK
# ALGN
# MS
# AMGN
# XOM
# ROK
# REGN
# LEN
# HIG
# DE
# POOL
# LMT
# WHR
# DRI
# EOG
# FRT
# BBWI
# CDNS
# NOC
# CAT
# DD
# HSY
# WYNN
# WELL
# FISV
# NI
# NWS
# EMR
# DUK
# ECL
# ABC
# APD
# MKC
# BKNG
# SEE
# EQR
# LYB
# ISRG
# UAA
# JCI
# LHX
# INCY
# SHW
# NXPI
# HPQ
# MCD
# ATO
# SJM
# TFX
# DLR
# ADI
# LUMN
# GWW
# UHS
# DHR
# MRNA
# FFIV
# ITW
# K
# MMC
# MSCI
# UPS
# CTAS
# GOOGL
# ORCL
# UNH
# UA
# JKHY
# PNW
# KMB
# CE
# PTC
# MAA
# CVX
# NCLH
# COST
# VRTX
# CPRT
# IQV
# SNPS
# EW
# BIO
# LNC
# WRB
# TWTR
# Not found
# AEE
# ANSS
# SPG
# CINF
# C
# DXCM
# KEYS
# ADP
# HBI
# IBM
# HPE
# DIS
# EXR
# ZION
# WU
# ALK
# EA
# LKQ
# TSN
# ACN
# ...
